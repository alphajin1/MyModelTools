# %%
import pandas as pd

df = pd.read_json("data/RankCTR0827.json", orient="record", lines=True)
df.head(5)
# Out:
#    rank  sum_expose  sum_click       ctr
# 0     1     1335257     220632  0.165236
# 1     2     1299605     118115  0.090885
# 2     3     1291494      84988  0.065806
# 3     4     1284700      59247  0.046117
# 4     5     1277738      44943  0.035174

# %%
import sweetviz as sv

my_report = sv.analyze(df)
my_report.show_html()
# Out:
# :FEATURES DONE:                    |█████████████████████| [100%]   00:01  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: no browser will pop up, the report is saved in your notebook/colab files.

# %%
import seaborn as sns

topRankDF = df[df["rank"] < 50]
sns.jointplot(x="rank", y="ctr", data=topRankDF)

# %%
import seaborn as sns

topRankDF = df[df["rank"] < 400]
sns.jointplot(x="rank", y="ctr", data=topRankDF)

# %%
tdf = df[df["rank"] <= 300]
tdf.shape
# Out:
# (300, 4)

# %%
import numpy as np
ctr_arr = np.array(tdf["ctr"].tolist())
rank_arr = np.array(tdf["rank"].tolist())
ctr_arr.shape, rank_arr.shape
# Out:
# ((300,), (300,))

# %%
ctr_arr_reformed = ctr_arr.reshape(ctr_arr.shape[0], -1)
rank_arr_reformed = rank_arr.reshape(rank_arr.shape[0], -1)
ctr_arr_reformed.shape, rank_arr_reformed.shape

# %%
from sklearn.linear_model import TweedieRegressor
# power = Poisson distribution
# alpha 
reg = TweedieRegressor(power=2, alpha=0.0, link='auto')
reg.fit(rank_arr_reformed, ctr_arr)

# %%
pred = reg.predict(rank_arr_reformed)
pred

# %%
reg.coef_

# %%
reg.intercept_

# %%
topRankDF.describe()

# %%
import math
topRankDF['log10CTR'] = topRankDF['ctr'].apply(lambda x: math.log10(x + 1))
topRankDF['loglog10CTR'] = topRankDF['ctr'].apply(lambda x: math.log10(math.log10(x + 1) + 1))
topRankDF['logeCTR'] = topRankDF['ctr'].apply(lambda x: math.log(x + 1))
# Out:
# ((300, 1), (300, 1))

# %%
from sklearn.linear_model import TweedieRegressor
# power = Poisson distribution
# alpha 
reg = TweedieRegressor(power=2, alpha=0.0, link='auto')
reg.fit(rank_arr_reformed, ctr_arr)
# Out:
# TweedieRegressor(alpha=0.0, power=2)

# %%
pred = reg.predict(rank_arr_reformed)
pred
# Out:
# array([0.01356149, 0.01348165, 0.01340228, 0.01332338, 0.01324494,
#        0.01316696, 0.01308944, 0.01301238, 0.01293577, 0.01285962,
#        0.01278391, 0.01270864, 0.01263382, 0.01255945, 0.0124855 ,
#        0.012412  , 0.01233893, 0.01226628, 0.01219407, 0.01212228,
#        0.01205091, 0.01197996, 0.01190943, 0.01183932, 0.01176962,
#        0.01170032, 0.01163144, 0.01156296, 0.01149489, 0.01142721,
#        0.01135994, 0.01129306, 0.01122657, 0.01116048, 0.01109477,
#        0.01102946, 0.01096452, 0.01089997, 0.0108358 , 0.01077201,
#        0.01070859, 0.01064554, 0.01058287, 0.01052056, 0.01045863,
#        0.01039705, 0.01033584, 0.01027499, 0.0102145 , 0.01015436,
#        0.01009458, 0.01003515, 0.00997607, 0.00991734, 0.00985895,
#        0.00980091, 0.00974321, 0.00968585, 0.00962883, 0.00957214,
#        0.00951578, 0.00945976, 0.00940407, 0.0093487 , 0.00929367,
#        0.00923895, 0.00918456, 0.00913049, 0.00907673, 0.00902329,
#        0.00897017, 0.00891736, 0.00886486, 0.00881267, 0.00876079,
#        0.00870921, 0.00865794, 0.00860697, 0.00855629, 0.00850592,
#        0.00845584, 0.00840606, 0.00835657, 0.00830737, 0.00825847,
#        0.00820985, 0.00816151, 0.00811346, 0.0080657 , 0.00801821,
#        0.00797101, 0.00792408, 0.00787743, 0.00783105, 0.00778495,
#        0.00773911, 0.00769355, 0.00764826, 0.00760323, 0.00755847,
#        0.00751397, 0.00746973, 0.00742575, 0.00738204, 0.00733858,
#        0.00729537, 0.00725242, 0.00720972, 0.00716728, 0.00712508,
#        0.00708314, 0.00704143, 0.00699998, 0.00695877, 0.0069178 ,
#        0.00687707, 0.00683659, 0.00679634, 0.00675632, 0.00671655,
#        0.00667701, 0.0066377 , 0.00659862, 0.00655977, 0.00652115,
#        0.00648276, 0.00644459, 0.00640665, 0.00636893, 0.00633144,
#        0.00629416, 0.00625711, 0.00622027, 0.00618365, 0.00614724,
#        0.00611105, 0.00607507, 0.00603931, 0.00600375, 0.00596841,
#        0.00593327, 0.00589834, 0.00586361, 0.00582909, 0.00579477,
#        0.00576066, 0.00572674, 0.00569303, 0.00565951, 0.00562619,
#        0.00559307, 0.00556014, 0.00552741, 0.00549487, 0.00546252,
#        0.00543036, 0.00539839, 0.0053666 , 0.00533501, 0.0053036 ,
#        0.00527238, 0.00524134, 0.00521048, 0.0051798 , 0.00514931,
#        0.00511899, 0.00508886, 0.0050589 , 0.00502911, 0.00499951,
#        0.00497007, 0.00494081, 0.00491172, 0.00488281, 0.00485406,
#        0.00482548, 0.00479707, 0.00476883, 0.00474076, 0.00471285,
#        0.0046851 , 0.00465752, 0.0046301 , 0.00460284, 0.00457574,
#        0.0045488 , 0.00452202, 0.0044954 , 0.00446893, 0.00444262,
#        0.00441647, 0.00439047, 0.00436462, 0.00433892, 0.00431338,
#        0.00428798, 0.00426274, 0.00423764, 0.00421269, 0.00418789,
#        0.00416324, 0.00413873, 0.00411436, 0.00409014, 0.00406606,
#        0.00404212, 0.00401832, 0.00399467, 0.00397115, 0.00394777,
#        0.00392453, 0.00390142, 0.00387845, 0.00385562, 0.00383292,
#        0.00381036, 0.00378792, 0.00376562, 0.00374345, 0.00372141,
#        0.0036995 , 0.00367772, 0.00365607, 0.00363455, 0.00361315,
#        0.00359188, 0.00357073, 0.00354971, 0.00352881, 0.00350804,
#        0.00348738, 0.00346685, 0.00344644, 0.00342615, 0.00340598,
#        0.00338593, 0.003366  , 0.00334618, 0.00332648, 0.00330689,
#        0.00328743, 0.00326807, 0.00324883, 0.0032297 , 0.00321069,
#        0.00319179, 0.003173  , 0.00315432, 0.00313575, 0.00311729,
#        0.00309893, 0.00308069, 0.00306255, 0.00304452, 0.0030266 ,
#        0.00300878, 0.00299107, 0.00297346, 0.00295595, 0.00293855,
#        0.00292125, 0.00290405, 0.00288695, 0.00286996, 0.00285306,
#        0.00283626, 0.00281956, 0.00280297, 0.00278646, 0.00277006,
#        0.00275375, 0.00273754, 0.00272142, 0.0027054 , 0.00268947,
#        0.00267364, 0.0026579 , 0.00264225, 0.00262669, 0.00261123,
#        0.00259586, 0.00258057, 0.00256538, 0.00255028, 0.00253526,
#        0.00252034, 0.0025055 , 0.00249075, 0.00247609, 0.00246151,
#        0.00244702, 0.00243261, 0.00241829, 0.00240405, 0.0023899 ,
#        0.00237583, 0.00236184, 0.00234794, 0.00233411, 0.00232037])

# %%
reg.coef_
# Out:
# array([-0.00828669])

# %%
reg.intercept_
# Out:
# -4.201261237110927

# %%
topRankDF.describe()
# Out:
#              rank    sum_expose      sum_click         ctr
# count  499.000000  4.990000e+02     499.000000  499.000000
# mean   250.000000  1.037392e+05    1777.533066    0.005196
# std    144.193157  2.138693e+05   10483.447860    0.009227
# min      1.000000  3.018000e+03       3.000000    0.000977
# 25%    125.500000  6.760000e+03      21.500000    0.003232
# 50%    250.000000  1.959700e+04      75.000000    0.003851
# 75%    374.500000  7.625550e+04     336.000000    0.004520
# max    499.000000  1.137035e+06  178670.000000    0.157137

# %%
import math
topRankDF['log10CTR'] = topRankDF['ctr'].apply(lambda x: math.log10(x + 1))
topRankDF['loglog10CTR'] = topRankDF['ctr'].apply(lambda x: math.log10(math.log10(x + 1) + 1))
topRankDF['logeCTR'] = topRankDF['ctr'].apply(lambda x: math.log(x + 1))
# Out:
# <ipython-input-20-d541d0116e5b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   topRankDF['log10CTR'] = topRankDF['ctr'].apply(lambda x: math.log10(x + 1))
# <ipython-input-20-d541d0116e5b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   topRankDF['loglog10CTR'] = topRankDF['ctr'].apply(lambda x: math.log10(math.log10(x + 1) + 1))
# <ipython-input-20-d541d0116e5b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   topRankDF['logeCTR'] = topRankDF['ctr'].apply(lambda x: math.log(x + 1))

# %%
topRankDF.head(10)
# Out:
#    rank  sum_expose  sum_click       ctr    logCTR  log10CTR   logeCTR
# 0     1     1137035     178670  0.157137 -0.803722  0.063385  0.145949
# 1     2     1075147     104070  0.096796 -1.014142  0.040126  0.092393
# 2     3     1049367      66959  0.063809 -1.195118  0.026864  0.061856
# 3     4     1037845      50646  0.048799 -1.311587  0.020692  0.047646
# 4     5     1037542      37374  0.036022 -1.443436  0.015369  0.035388
# 5     6     1020062      31126  0.030514 -1.515503  0.013054  0.030058
# 6     7     1011521      25705  0.025412 -1.594957  0.010898  0.025095
# 7     8     1008045      24564  0.024368 -1.613181  0.010456  0.024076
# 8     9     1003515      20236  0.020165 -1.695399  0.008670  0.019964
# 9    10      998395      19560  0.019591 -1.707934  0.008426  0.019402

# %%
import seaborn as sns

sns.jointplot(x="rank", y="loglog10CTR", data=topRankDF)

# %%
import matplotlib.pyplot as plt

plt.scatter(topRankDF["rank"], topRankDF["ctr"])
plt.scatter(topRankDF["rank"], topRankDF["log10CTR"])
plt.scatter(topRankDF["rank"], topRankDF["loglog10CTR"])
plt.show()
